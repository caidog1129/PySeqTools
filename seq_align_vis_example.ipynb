# %%
# !pip install PySeqTools==0.1.5
#!pip install pandas
#!pip install pandas --upgrade
#!pip install networkx 
#!pip install matplotlib
#!pip install random
#!pip install numpy --upgrade
#!pip install numpy --upgrade --ignore-installed
#!pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seq-align-two-vars in /home/jc092/.local/lib/python3.9/site-packages (0.1.2)
# Collecting seq-align-two-vars
#   Downloading seq_align_two_vars-0.1.3-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: seq-align-two-vars
#   Attempting uninstall: seq-align-two-vars
#     Found existing installation: seq_align_two_vars 0.1.2
#     Uninstalling seq_align_two_vars-0.1.2:
#       Successfully uninstalled seq_align_two_vars-0.1.2
# Successfully installed seq-align-two-vars-0.1.3
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt
import random
from PySeqTools import PySeqTools as seq

# %%
df = seq.make_sample(10, ["A","B","C","D","E"], 50, distribution = np.random.normal, var_len=True, seed = 42, normalized = True)

# %%
seq.draw(df,[4])

# %%
seq.draw(df, [1,2,3])

# %%
df = seq.normalize(df)

# %%
seq.draw(df, [1,2,3])

# %%
dis = seq.distance_metric(df)

# %%
dis
# Out:
# array([[0.    , 6.5552, 3.9327, ..., 4.6944, 1.8714, 7.2566],
#        [6.5552, 0.    , 4.4604, ..., 2.5534, 4.5704, 7.126 ],
#        [3.9327, 4.4604, 0.    , ..., 6.4234, 4.5015, 8.0854],
#        ...,
#        [4.6944, 2.5534, 6.4234, ..., 0.    , 5.8667, 5.6519],
#        [1.8714, 4.5704, 4.5015, ..., 5.8667, 0.    , 4.842 ],
#        [7.2566, 7.126 , 8.0854, ..., 5.6519, 4.842 , 0.    ]])

# %%
model = seq.cluster(dis, n_clusters=4)

# %%
seq.plot_dendrogram(model, truncate_mode= "level", p = 4)

# %%
seq.draw(df,[15,34])

# %%
dis[15][34]
# Out:
# 0.1799999999999995

# %%
dis[43,28]
# Out:
# 6.906300000000001

# %%
seq.neighbours(dis, 12, 5)
# Out:
# [6, 7, 12, 13, 21, 28, 29, 36, 37, 39]

# %%
dis[44,45]
# Out:
# 5.049600000000002

# %%
dis[16,24]
# Out:
# 5.046499999999999

# %%
seq.draw(df,[16,24])

# %%
G = nx.gnp_random_graph(12, .6, directed=True,seed=1)
nx.draw(G)
df2 = random_walk(G,6,20)

# %%
dis = seq.distance_metric(df2)

# %%
df2
# Out:
#                  category                                         1  \
# 0    [4, 11, 3, 11, 7, 0]   [0.6319, 0.7565, 0.4824, 0.993, 0.0249]
# 1      [8, 1, 6, 0, 4, 3]  [0.2993, 0.5874, 0.6588, 0.7135, 0.7209]
# 2     [0, 10, 2, 9, 8, 1]     [0.3165, 1.0, 0.6945, 0.3095, 0.9286]
# 3     [6, 0, 4, 8, 11, 2]  [0.0817, 0.6589, 0.6707, 0.0884, 0.3153]
# 4    [8, 11, 4, 7, 4, 11]  [0.8735, 0.6765, 0.9257, 0.4274, 0.3368]
# 5    [9, 5, 2, 1, 10, 11]  [0.5212, 0.5843, 0.2865, 0.0167, 0.9003]
# 6    [6, 10, 1, 10, 4, 7]  [0.2291, 0.8856, 0.6833, 0.7832, 0.1598]
# 7      [1, 4, 3, 7, 8, 0]  [0.2601, 0.0477, 0.1056, 0.0412, 0.7324]
# 8   [11, 3, 11, 6, 4, 11]   [0.636, 0.7436, 0.2357, 0.5775, 0.0399]
# 9     [1, 6, 3, 10, 3, 0]  [0.3126, 0.5639, 0.4737, 0.9315, 0.4189]
# 10    [2, 9, 5, 10, 4, 7]   [0.3301, 0.2503, 0.829, 0.4013, 0.3278]
# 11    [1, 9, 6, 11, 6, 4]  [0.6695, 0.8082, 0.7365, 0.9067, 0.8701]
# 12  [10, 1, 11, 4, 8, 11]  [0.9173, 0.3223, 0.8765, 0.7938, 0.3969]
# 13   [4, 3, 11, 4, 7, 11]     [0.9008, 0.8188, 0.0, 0.5784, 0.4624]
# 14    [0, 9, 3, 10, 5, 1]   [0.4617, 0.9504, 0.211, 0.2219, 0.9411]
# 15   [1, 10, 3, 0, 4, 11]  [0.1837, 0.6811, 0.7956, 0.9208, 0.9427]
# 16     [5, 2, 7, 1, 4, 3]  [0.1909, 0.0401, 0.0591, 0.3841, 0.2117]
# 17    [10, 1, 0, 9, 1, 9]     [0.7683, 0.87, 0.8093, 0.214, 0.7307]
# 18    [4, 8, 10, 5, 4, 8]  [0.1373, 0.1286, 0.4915, 0.7997, 0.6632]
# 19    [0, 9, 7, 1, 3, 10]  [0.9803, 0.9148, 0.9141, 0.7098, 0.1704]
#
#                                            2
# 0   [0.5125, 0.3177, 0.3177, 0.5158, 0.2812]
# 1      [0.6686, 0.6491, 0.4584, 0.3301, 1.0]
# 2       [0.3115, 0.4365, 0.448, 0.0, 0.6686]
# 3    [0.4584, 0.3301, 0.5739, 0.328, 0.8824]
# 4    [0.328, 0.5125, 0.8068, 0.8068, 0.5125]
# 5   [0.6122, 0.0846, 0.5925, 0.6452, 0.4313]
# 6   [0.3434, 0.6452, 0.6452, 0.1276, 0.8068]
# 7      [0.7368, 1.0, 0.7606, 0.6771, 0.6849]
# 8   [0.3177, 0.3177, 0.2429, 0.3527, 0.5125]
# 9     [0.6491, 0.5203, 0.468, 0.468, 0.4019]
# 10   [0.448, 0.6122, 0.8221, 0.1276, 0.8068]
# 11   [0.4319, 0.612, 0.2429, 0.2429, 0.3527]
# 12   [0.6452, 0.4948, 0.5125, 0.5739, 0.328]
# 13     [1.0, 0.3177, 0.5125, 0.8068, 0.5158]
# 14   [0.3273, 0.7018, 0.468, 0.8221, 0.4154]
# 15   [0.6452, 0.468, 0.4019, 0.3301, 0.5125]
# 16     [0.0846, 0.6633, 0.6296, 0.7368, 1.0]
# 17   [0.6452, 0.498, 0.3273, 0.4319, 0.4319]
# 18   [0.5739, 0.512, 0.8221, 0.5892, 0.5739]
# 19   [0.3273, 0.1067, 0.6296, 0.1396, 0.468]

# %%
seq.draw(df2,[1,2,3,4,5])

# %%
G = nx.cycle_graph(10)
nx.draw(G)
df3 = seq.random_walk(G,6,20)
df3
# Out:
#               category                                         1  \
# 0   [0, 1, 0, 1, 0, 9]   [0.615, 0.8482, 0.0239, 0.3478, 0.1752]
# 1   [1, 2, 3, 4, 5, 4]  [0.3676, 0.8374, 0.1092, 0.4136, 0.1195]
# 2   [7, 6, 7, 6, 5, 6]      [0.745, 0.6582, 0.0, 0.1306, 0.8049]
# 3   [0, 1, 2, 1, 2, 3]     [0.174, 0.372, 0.2919, 0.3298, 0.303]
# 4   [8, 9, 8, 9, 0, 9]  [0.3486, 0.9757, 0.3175, 0.1553, 0.1854]
# 5   [4, 5, 4, 5, 4, 3]   [0.2046, 0.1917, 0.0838, 0.1056, 0.611]
# 6   [3, 2, 3, 4, 3, 2]  [0.6616, 0.3894, 0.8858, 0.5672, 0.1683]
# 7   [2, 1, 2, 1, 2, 3]  [0.0519, 0.6818, 0.4877, 0.5976, 0.5464]
# 8   [9, 8, 9, 0, 1, 2]  [0.3584, 0.3915, 0.6398, 0.8026, 0.7144]
# 9   [9, 0, 9, 0, 9, 0]   [0.7336, 0.6672, 0.668, 0.4806, 0.6373]
# 10  [4, 3, 4, 3, 2, 1]   [0.6038, 0.7122, 0.648, 0.8571, 0.4864]
# 11  [6, 7, 6, 5, 6, 5]  [0.1227, 0.0093, 0.1372, 0.4443, 0.5154]
# 12  [5, 6, 7, 6, 7, 8]   [0.3719, 0.2221, 0.055, 0.1889, 0.2864]
# 13  [2, 1, 2, 3, 2, 3]  [0.6034, 0.1693, 0.5337, 0.4756, 0.4498]
# 14  [9, 0, 1, 0, 1, 2]  [0.3719, 0.1299, 0.6329, 0.3364, 0.4822]
# 15  [5, 6, 5, 4, 5, 4]   [0.698, 0.6735, 0.0055, 0.1613, 0.1719]
# 16  [9, 8, 7, 8, 9, 0]  [0.1461, 0.9612, 0.2203, 0.8544, 0.4454]
# 17  [2, 1, 2, 3, 4, 5]   [0.8984, 0.452, 0.1849, 0.5751, 0.8711]
# 18  [3, 4, 3, 2, 3, 2]  [0.6183, 0.1907, 0.2272, 0.3553, 0.6157]
# 19  [1, 2, 3, 4, 3, 2]      [0.5803, 0.666, 0.3392, 0.2748, 1.0]
#
#                                            2
# 0     [0.072, 0.5001, 0.7195, 0.377, 0.9862]
# 1    [0.3402, 0.7944, 0.8658, 0.701, 0.6835]
# 2   [0.3076, 0.8681, 0.6108, 0.3095, 0.1431]
# 3   [0.0106, 0.0948, 0.8055, 0.4349, 0.9857]
# 4   [0.6552, 0.6023, 0.1085, 0.2987, 0.2783]
# 5   [0.0677, 0.2992, 0.4993, 0.6496, 0.1479]
# 6   [0.7571, 0.3037, 0.0762, 0.2264, 0.1632]
# 7   [0.7402, 0.8688, 0.0448, 0.7601, 0.0238]
# 8    [0.8022, 0.3075, 0.008, 0.8988, 0.5359]
# 9       [0.6209, 0.0747, 0.084, 0.7628, 1.0]
# 10  [0.7781, 0.0259, 0.8938, 0.5668, 0.4746]
# 11  [0.1025, 0.1436, 0.6231, 0.7653, 0.1632]
# 12   [0.9261, 0.6089, 0.2453, 0.266, 0.2212]
# 13   [0.2809, 0.774, 0.2078, 0.9542, 0.5391]
# 14  [0.2518, 0.8827, 0.0444, 0.8021, 0.3845]
# 15   [0.4305, 0.4506, 0.653, 0.4725, 0.7836]
# 16     [0.3488, 0.0, 0.7204, 0.3784, 0.3488]
# 17  [0.7869, 0.9215, 0.5653, 0.2325, 0.4261]
# 18    [0.8852, 0.705, 0.9688, 0.9135, 0.522]
# 19  [0.4239, 0.7745, 0.2581, 0.7309, 0.9241]

# %%
dis = seq.distance_metric(df3)

# %%
model = seq.cluster(dis, n_clusters=6)

# %%
seq.plot_dendrogram(model, truncate_mode= "level", p = 4)

# %%
seq.draw(df3, [1,2,3,4,5])
