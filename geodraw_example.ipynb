# %%
# !pip install PySeqTools==0.1.5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import networkx as nx
from matplotlib import pyplot as plt
import random
from PySeqTools import PySeqTools as seq

# %%
seqence = [
    {"index":0, "location":["PIT","PHL","MDT","BFD"], "category": ["Large", "Large", "Medium", "Small"], 1: [0.2, 0.3, 0.1], 2:[0.3, 0.5, 0.1]},
    {"index":1, "location":["IPT","PHL","PIT","ERI"], "category": ["Small", "Large", "Large", "Small"], 1: [0.1, 0.7, 0.3], 2:[0.4, 0.2, 0.6]}
]

df = pd.DataFrame(seqence)
df.set_index("index", inplace=True)

# %%
df
# Out:
#                    location                       category                1  \
# index
# 0      [PIT, PHL, MDT, BFD]  [Large, Large, Medium, Small]  [0.2, 0.3, 0.1]
# 1      [IPT, PHL, PIT, ERI]   [Small, Large, Large, Small]  [0.1, 0.7, 0.3]
#
#                      2
# index
# 0      [0.3, 0.5, 0.1]
# 1      [0.4, 0.2, 0.6]

# %%
# Create a list of dictionaries with airport information
airports = [
    {"name": "PHL", "lat": 39.8719, "long": -75.2411, "category": "Large"},
    {"name": "PIT", "lat": 40.4915, "long": -80.2329, "category": "Large"},
    {"name": "MDT", "lat": 40.1940, "long": -76.7634, "category": "Medium"},
    {"name": "ABE", "lat": 40.6524, "long": -75.4342, "category": "Medium"},
    {"name": "AVP", "lat": 41.3389, "long": -75.7243, "category": "Medium"},
    {"name": "SCE", "lat": 40.8499, "long": -77.8479, "category": "Small"},
    {"name": "LBE", "lat": 40.2767, "long": -79.4040, "category": "Small"},
    {"name": "ERI", "lat": 42.0833, "long": -80.1750, "category": "Small"},
    {"name": "IPT", "lat": 41.2411, "long": -76.9214, "category": "Small"},
    {"name": "BFD", "lat": 41.8025, "long": -78.6406, "category": "Small"}
]

# Create a pandas data frame from the list of dictionaries
df_loc = pd.DataFrame(airports)
df_loc.set_index("name", inplace=True)

# %%
df_loc
# Out:
#           lat     long category
# name
# PHL   39.8719 -75.2411    Large
# PIT   40.4915 -80.2329    Large
# MDT   40.1940 -76.7634   Medium
# ABE   40.6524 -75.4342   Medium
# AVP   41.3389 -75.7243   Medium
# SCE   40.8499 -77.8479    Small
# LBE   40.2767 -79.4040    Small
# ERI   42.0833 -80.1750    Small
# IPT   41.2411 -76.9214    Small
# BFD   41.8025 -78.6406    Small

# %%
seq.geo_draw(df, [0,1], df_loc)

# %%
# How to generate your graph, please see https://towardsdatascience.com/easy-steps-to-plot-geographic-data-on-a-map-python-11217859a2db
map1 = plt.imread("paper_data/map.png")

# %%
seq.geo_draw(df, [0,1], df_loc, use_map = True, map1 = map1)
